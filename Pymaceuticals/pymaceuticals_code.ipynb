# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# -

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Import data files.
mouse_data_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the files.
mouse_data = pd.read_csv(mouse_data_path)
study_results = pd.read_csv(study_results_path)

# %%
# Show the mouse data.
mouse_data.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
# Show the study results.
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine both files into a single Dataframe.
complete_mouse_data = pd.merge(study_results, mouse_data, how="left", on=["Mouse ID", "Mouse ID"] )
complete_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Find the number of mice.
total_mice = mouse_data["Mouse ID"].count()
total_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint.
duplicates = complete_mouse_data[complete_mouse_data.duplicated(subset=['Mouse ID', 'Timepoint'])]

# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mouse_ids = duplicates['Mouse ID'].unique()
duplicate_mouse_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Get all the data for the duplicate mouse ID.
duplicate_mouse_data = complete_mouse_data.loc[complete_mouse_data["Mouse ID"] =="g989"]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# 329   Female          21          26
# 360   Female          21          26
# 620   Female          21          26
# 681   Female          21          26
# 815   Female          21          26
# 869   Female          21          26
# 950   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# 1380  Female          21          26
# 1592  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_data = complete_mouse_data[complete_mouse_data['Mouse ID'].isin(duplicate_mouse_ids)==False]
clean_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Check the number of mice in the clean DataFrame.
total_mice_2 = len(clean_mouse_data.groupby("Mouse ID").count())
total_mice_2
# Out:
# 248

# %% [markdown]
# # Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
mean_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].mean()
median_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].median()
var_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].var()
std_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].std()
sem_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].sem()

# Assemble the resulting series into a single summary DataFrame.
summary = pd.DataFrame({'Mean Tumor Volume' : mean_tumor_volume,
                        'Median Tumor Volume' : median_tumor_volume,
                        'Tumor Volume Variance': var_tumor_volume,
                        'Tumor Volume Std. Dev.' : std_tumor_volume,
                        'Tumor Volume Std. Err.' : sem_tumor_volume})
summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
agg_summary = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].agg(["mean", "median", "var", "std", "sem"])
agg_summary
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# # Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_regimen_pdplot = clean_mouse_data[("Drug Regimen")].value_counts()
drug_regimen_pdplot.columns = [("Drug Regimen", "Mouse ID")]
drug_regimen_pdplot.plot(kind="bar", xlabel="Drug Regimen",ylabel="Number of Observed Mouse ID's", title="Total Rows per Drug Regimen", figsize=(10, 6), color= "teal")
# drug_regimen_pdplot.texts = []
# Out:
# <Axes: title={'center': 'Total Rows per Drug Regimen'}, xlabel='Drug Regimen', ylabel="Number of Observed Mouse ID's">

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
# drug_regimen_pyplot = clean_mouse_data["Drug Regimen"].value_counts()
# drug_names = clean_mouse_data["Drug Regimen"].value_counts()
mouse_count = clean_mouse_data.groupby(["Drug Regimen", "Mouse ID"]).count()
plt.bar(mouse_count, align="center", height=1)
plt.figure(figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       1 # Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
#       2 # drug_regimen_pyplot = clean_mouse_data["Drug Regimen"].value_counts()
#       3 # drug_names = clean_mouse_data["Drug Regimen"].value_counts()
#       4 mouse_count = clean_mouse_data.groupby(["Drug Regimen", "Mouse ID"]).count()
# ----> 5 plt.bar(mouse_count, align="center", height=1)
#       6 plt.figure(figsize=(10,6))
#
# File c:\Users\Public\Newfolder\envs\dev\lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File c:\Users\Public\Newfolder\envs\dev\lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Public\Newfolder\envs\dev\lib\site-packages\matplotlib\axes\_axes.py:2524, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2521 args = zip(left, bottom, width, height, color, edgecolor, linewidth,
#    2522            hatch, patch_labels)
#    2523 for l, b, w, h, c, e, lw, htch, lbl in args:
# -> 2524     r = mpatches.Rectangle(
#    2525         xy=(l, b), width=w, height=h,
#    2526         facecolor=c,
#    2527         edgecolor=e,
#    2528         linewidth=lw,
#    2529         label=lbl,
#    2530         hatch=htch,
#    2531         )
#    2532     r._internal_update(kwargs)
#    2533     r.get_path()._interpolation_steps = 100
#
# File c:\Users\Public\Newfolder\envs\dev\lib\site-packages\matplotlib\patches.py:718, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     694 @_docstring.dedent_interpd
#     695 def __init__(self, xy, width, height, *,
#     696              angle=0.0, rotation_point='xy', **kwargs):
#     697     """
#     698     Parameters
#     699     ----------
#    (...)
#     716         %(Patch:kwdoc)s
#     717     """
# --> 718     super().__init__(**kwargs)
#     719     self._x0 = xy[0]
#     720     self._y0 = xy[1]
#
# File c:\Users\Public\Newfolder\envs\dev\lib\site-packages\matplotlib\patches.py:91, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      88 self._dash_pattern = (0, None)  # offset, dash (scaled by linewidth)
#      90 self.set_linestyle(linestyle)
# ---> 91 self.set_linewidth(linewidth)
#      92 self.set_antialiased(antialiased)
#      93 self.set_hatch(hatch)
#
# File c:\Users\Public\Newfolder\envs\dev\lib\site-packages\matplotlib\patches.py:391, in Patch.set_linewidth(self, w)
#     389 if w is None:
#     390     w = mpl.rcParams['patch.linewidth']
# --> 391 self._linewidth = float(w)
#     392 self._dash_pattern = mlines._scale_dashes(
#     393     *self._unscaled_dash_pattern, w)
#     394 self.stale = True
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# # Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# # Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# # Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
