# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# -

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Import data files.
mouse_data_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the files.
mouse_data = pd.read_csv(mouse_data_path)
study_results = pd.read_csv(study_results_path)

# %%
# Show the mouse data.
mouse_data.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
# Show the study results.
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine both files into a single Dataframe.
complete_mouse_data = pd.merge(study_results, mouse_data, how="left", on=["Mouse ID", "Mouse ID"] )
complete_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Find the number of mice.
total_mice = mouse_data["Mouse ID"].count()
print(f"The total number of mice is {total_mice}")
# Out:
# The total number of mice is 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint.
duplicates = complete_mouse_data[complete_mouse_data.duplicated(subset=['Mouse ID', 'Timepoint'])]

# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mouse_ids = duplicates['Mouse ID'].unique()
duplicate_mouse_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Get all the data for the duplicate mouse ID.
duplicate_mouse_data = complete_mouse_data.loc[complete_mouse_data["Mouse ID"] =="g989"]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_data = complete_mouse_data[complete_mouse_data['Mouse ID'].isin(duplicate_mouse_ids)==False]
clean_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Check the number of mice in the clean DataFrame.
total_mice_2 = len(clean_mouse_data.groupby("Mouse ID").count())
print(f"The total number of mice in the clean Dataframe is {total_mice_2}")
# Out:
# The total number of mice in the clean Dataframe is 248

# %% [markdown]
# # Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
mean_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].mean()
median_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].median()
var_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].var()
std_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].std()
sem_tumor_volume = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].sem()

# Assemble the resulting series into a single summary DataFrame.
summary = pd.DataFrame({'Mean Tumor Volume' : mean_tumor_volume,
                        'Median Tumor Volume' : median_tumor_volume,
                        'Tumor Volume Variance': var_tumor_volume,
                        'Tumor Volume Std. Dev.' : std_tumor_volume,
                        'Tumor Volume Std. Err.' : sem_tumor_volume})
summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
agg_summary = clean_mouse_data.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].agg(["mean", "median", "var", "std", "sem"])
agg_summary
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# # Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_regimen_pdplot = clean_mouse_data[("Drug Regimen")].value_counts()
drug_regimen_pdplot.columns = [("Drug Regimen", "Mouse ID")]
drug_regimen_pdplot.plot(kind="bar", xlabel="Drug Regimen",ylabel="Number of Observed Mouse ID's", title="Total Rows per Drug Regimen", figsize=(10, 6), color= "teal")
drug_regimen_pdplot.texts = []

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
drug_name_count = clean_mouse_data["Drug Regimen"].value_counts()
drug_name = drug_name_count.index
mouse_count =  drug_name_count.values#clean_mouse_data.groupby(["Drug Regimen"])["Mouse ID"].count()
plt.figure(figsize=(10,6))
plt.title("Total Rows per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Observed Mouse ID's")
plt.xticks(rotation= 90)
plt.bar(drug_name, mouse_count, align="center", color="purple")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mouse_gender = clean_mouse_data["Sex"].value_counts()
mouse_gender.plot(kind="pie", ylabel="Sex", colors=("purple", "lightcoral"), startangle=0, autopct="%1.1f%%", title="Distribution of Male & Female Mice")
mouse_gender.texts = []

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_pyplot = clean_mouse_data["Sex"].value_counts()
labels = gender_pyplot.index
size = gender_pyplot.values
colors = ["skyblue", "teal"]
plt.figure(figsize=(8,6))
plt.pie(size, labels=labels, colors=colors, autopct="%1.1f%%", startangle=0)
plt.title("Distribution of Male & Female Mice")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# # Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint =clean_mouse_data.groupby(["Mouse ID"])["Timepoint"].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merge_data = pd.merge(last_timepoint, clean_mouse_data, on= ["Mouse ID", "Timepoint"], how="left")
final_tmr_vol = merge_data[merge_data["Drug Regimen"].isin(regimens)]
final_tmr_vol
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 3       a275         45           62.999356                 3     Ceftamin
# 6       a411         45           38.407618                 1     Ramicane
# 7       a444         45           43.047543                 0     Ramicane
# ..       ...        ...                 ...               ...          ...
# 238     y769         45           68.594745                 4     Ceftamin
# 239     y793         45           31.896238                 2    Capomulin
# 240     y865         45           64.729837                 3     Ceftamin
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
tmr_vols = []
tmr_vol_per_drug = {}
outliers_per_treatment = {}
for name in regimens:
    treatment_data = final_tmr_vol[final_tmr_vol["Drug Regimen"] == name]
    tmr_vol = treatment_data["Tumor Volume (mm3)"]
    tmr_vols.append(tmr_vol)
    tmr_vol_per_drug[name] = tmr_vol

# Calculate the IQR and quantitatively determine if there are any potential outliers.
quartiles = tmr_vol.quantile([0.25, 0.75])
lower_q = quartiles[0.25]
upper_q = quartiles[0.75]
iqr = upper_q - lower_q

lower_bound = lower_q - (1.5 * iqr)
upper_bound = upper_q + (1.5 * iqr)
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
outliers = treatment_data[treatment_data["Tumor Volume (mm3)"] < lower_bound] | (treatment_data["Tumor Volume (mm3)"] > upper_bound)

    # add subset 
subset_data =tmr_vol
    
    # Determine outliers using upper and lower bounds
outliers = tmr_vol[(tmr_vol < lower_bound)| (tmr_vol > upper_bound)]
outliers_per_treatment[name] = outliers
print(f"Capomulin's potential outliers:")
print(f"Ramicane's potential outliers:")
print(f"Infubinol's potential outliers:")
print(f"Ceftamin's potential outliers:")
# Out:
# Capomulin's potential outliers:
# Ramicane's potential outliers:
# Infubinol's potential outliers:
# Ceftamin's potential outliers:

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.figure(figsize=(10, 6))
plt.boxplot(tmr_vols, labels=regimens, flierprops=dict(marker="s", markerfacecolor="blue", markersize=10))
plt.title("Tumor Volume Distribution for each Treatment Group")
plt.xlabel("Treatment Group")
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# # Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse_id = "l509"
drug = "Capomulin"
mouse = clean_mouse_data[(clean_mouse_data["Mouse ID"] == mouse_id) & (clean_mouse_data["Drug Regimen"] == drug)]
mouse = mouse.sort_values(by= "Timepoint")
plt.figure(figsize=(10, 6))
plt.plot(mouse["Timepoint"], mouse["Tumor Volume (mm3)"], linestyle="-", color="g")
plt.title("Capomulin Treatment of Mouse l509")
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_regimen = complete_mouse_data[complete_mouse_data["Drug Regimen"] == "Capomulin"]
weight = capomulin_regimen.groupby(["Mouse ID"])["Weight (g)"].first()
avg_tmr_vol = capomulin_regimen.groupby(["Mouse ID"])["Tumor Volume (mm3)"].mean()

plt.figure(figsize= (10, 6))
plt.scatter(weight, avg_tmr_vol, color="r", marker="o")
plt.title("Mouse Weight vs. Average Observed Tumor Volume for Capomulin")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# # Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = weight.corr(avg_tmr_vol)
print(f"The correlation between mouse weight and the average tumor volume is {correlation:.2f} ")

(slope, intercept, r, pvalue, stder) = st.linregress(weight, avg_tmr_vol)
regression = weight * slope + intercept
plt.figure(figsize=(10, 6))
plt.scatter(weight, avg_tmr_vol, color="r", marker="o")
plt.plot(weight,regression, "-")
plt.title("Mouse Weight and Average Observed Tumor Volume for Capomulin")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
